# %% [markdown]
# # Matplotlib line plot

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# 一條折線圖

# %%
plt.plot([1,2,3],[2,4,6])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# 兩條折線圖

# %%
plt.plot([1,2,3],[[2,4],[4,8],[6,12]])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# 設定字型

# %%
plt.rc("font", family = "Arial Unicode Ms")

# %%
plt.plot(
    [2,3,4],
    [[4,2],[6,7],[8,9]],
    label = ["第一組標籤","第二組標籤"])
plt.legend()
plt.xlabel("我是x_label")
plt.ylabel("我是y_label")
# Out:
# Text(0, 0.5, '我是y_label')

# %%
查看有哪些字體

# %%
from matplotlib.font_manager import FontManager
fm = FontManager()
mat_fonts = set(f.name for f in fm.ttflist)
print(mat_fonts)
# Out:
# {'STIXIntegralsSm', 'Avenir Next', 'Arial Black', 'Marion', 'Lao Sangam MN', 'Noto Sans Gunjala Gondi', 'Farah', 'YuMincho', 'Seravek', 'DejaVu Sans Mono', 'Noto Sans Bhaiksuki', 'Al Bayan', 'Noto Sans Ol Chiki', 'Baoli SC', 'InaiMathi', 'Sama Tamil', 'Noto Sans Vai', 'PCMyungjo', 'Ayuthaya', 'Diwan Thuluth', '.SF Camera', 'Lava Kannada', 'Noto Sans New Tai Lue', 'Courier New', 'Gujarati MT', 'STIXIntegralsD', 'Euphemia UCAS', 'Noto Sans Mandaic', 'October Compressed Tamil', 'STIXSizeThreeSym', 'Tiro Devanagari Marathi', 'STHeiti', 'PilGi', 'Savoye LET', 'Times New Roman', 'Noto Sans Hanifi Rohingya', 'Noto Sans Cham', 'Noto Sans Old Persian', 'Sathu', 'HanziPen SC', 'Sama Malayalam', 'BM Dohyeon', 'Lao MN', 'Snell Roundhand', 'American Typewriter', 'Noto Sans Glagolitic', 'STIX Two Text', 'Noto Sans Armenian', 'Noto Sans Tai Viet', 'AkayaKanadaka', 'Noto Sans Siddham', 'Noto Sans Old South Arabian', 'Sama Kannada', 'Noto Sans Myanmar', 'Noto Sans Mende Kikakui', 'Baskerville', '.SF 
# ...

# %% [markdown]
# 讀檔＋畫圖

# %%
import csv
file = open("data.csv", encoding = "utf-8-sig")
reader = csv.reader(file)
header = next(reader)
print("標題",header)
x = []
y = []
for row in reader:
    print("每列資料",row)
    x.append(int(row[0]))
    y.append([int(row[1]), int(row[2]), int(row[3])])
plt.plot(x, y ,label = header[1:4])
plt.legend()
plt.xlabel(header[0])
plt.ylabel("釣到的魚")
plt.show()
# Out:
# 標題 ['年度', '鯖魚', '鮭魚', '鯊魚']
# 每列資料 ['2021', '4000', '2000', '3765']
# 每列資料 ['2022', '3500', '2500', '5428']
# 每列資料 ['2023', '3000', '3000', '2714']
# 每列資料 ['2024', '2500', '4000', '5432']
# 每列資料 ['2025', '2000', '6000', '3456']
